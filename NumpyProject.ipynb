# %%
import pandas as pd

# %%
data = {
    "EmpID":[101,102,103,104,105],
    "Name":["Alice","Bob","Charlie","David","Emma"],
    "Age":[25,30,28,35,26],
    "Dept":["HR","IT","Finance","IT","HR"],
    "Salary":[55000,72000,68000,88000,60000],
    "Experience":[1,4,3,8,2]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    EmpID     Name  Age     Dept  Salary  Experience
# 0    101    Alice   25       HR   55000           1
# 1    102      Bob   30       IT   72000           4
# 2    103  Charlie   28  Finance   68000           3
# 3    104    David   35       IT   88000           8
# 4    105     Emma   26       HR   60000           2

# %%
df.head(3)
# Out:
#    EmpID     Name  Age     Dept  Salary  Experience
# 0    101    Alice   25       HR   55000           1
# 1    102      Bob   30       IT   72000           4
# 2    103  Charlie   28  Finance   68000           3

# %%
df[df['Dept']== 'IT']
# Out:
#    EmpID   Name  Age Dept  Salary  Experience
# 1    102    Bob   30   IT   72000           4
# 3    104  David   35   IT   88000           8

# %%
df["Salary"].mean()
# Out:
# 68600.0

# %%
df[df['Salary'] >= 60000]
# Out:
#    EmpID     Name  Age     Dept  Salary  Experience
# 1    102      Bob   30       IT   72000           4
# 2    103  Charlie   28  Finance   68000           3
# 3    104    David   35       IT   88000           8
# 4    105     Emma   26       HR   60000           2

# %%
df['Bonus']= df['Salary']*0.10
print(df)
# Out:
#    EmpID     Name  Age     Dept  Salary  Experience   Bonus
# 0    101    Alice   25       HR   55000           1  5500.0
# 1    102      Bob   30       IT   72000           4  7200.0
# 2    103  Charlie   28  Finance   68000           3  6800.0
# 3    104    David   35       IT   88000           8  8800.0
# 4    105     Emma   26       HR   60000           2  6000.0

# %%
import numpy as np

# %%
np.mean(df['Salary'])
# Out:
# 68600.0

# %%
min= np.min(df['Salary'])
min
# Out:
# 55000
